# %% [markdown]
# # Final project

# %% [markdown]
# ## Introduction/problem

# %% [markdown]
# ##### I'm an architecture fascinated by Hassan 2 Mosq of Casablanca city, and i'm planning to visit it next month. I need your help to chose the best hotel for my journey. I want a good rated hotel, not far from the mosq with positive tips. please help me.

# %% [markdown]
# ## Data

# %% [markdown]
# #### So for this analysis, we used location data from foursquare.com.  We used a search query based on the location of the mosq to identify the list of hotels in proximity and then we employed the decision three algorithm to make the final decision about the hotel of the journey.
# #### Using this data will allow exploration and examination to answer the questions. The neighbourhood data will enable us to properly group hotels around the mosq. Hotel’s locations of interest will then allow us to cluster and quantitatively understand the venues most common to that location.

# %% [markdown]
# ### Methodologie

# %% [markdown]
# #### The methodology will include:
# #### 1.	First, we import the conveniant libraries
# #### 2.	Then we insert the foursquare ids
# #### 3.	Now, we insert the mosq adress to get its latitude and longitude
# #### 4.	We define our search query as "hotel"
# #### 5.	Then we create our URL
# #### 6.	We get the Json file
# #### 7.	We clean the dataframe
# #### 8.	We generate a map centred around the mosq
# #### 9.	Create an URL to show the rating of the closest hotelto the mosq
# #### 10.Create an URL to show the rating of the second closest hotelto the mosq
# #### 11.Create an URL to show the rating of the third closest hotelto the mosq
# #### 12.We import DecisionThree Classifier

# %% [markdown]
# ### Results

# %% [markdown]
# #### The analysis enabled us to discover and describe visually and quantitatively:
# #### 1.	The list of hotels around Hassan II mosq
# #### 2.	The mapping of the hotels
# #### 3.	The classification of the best hotels by their distance from the mosq
# #### 4.	The rating of the three closest hotels

# %% [markdown]
# ### Discussion and Recommendations

# %% [markdown]
# #### There are many hotels around the Hassan II mosq of Casablanca, but based on distance and rating criteria, the analysis allowed us to chose the best option. We can improve this study by looking for more details data about Casablanca city, to take other features into consideration while making our choice.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# #### Using Foursquare venue data we were able to analyze, discover and describe venues by locations of interest.
# #### While overall, the City of Fredericton Open Data is interesting, it misses the details required for true valued quantitative analysis and predictive analytics which would be most valued by tourists
# #### The Open Data project is a great start and empowers the need for a "Citizens Like Me" model to be developed where Casablanca visitors are able to share their data as they wish for detailed analysis that enables the creation of valued services.

# %% [markdown]
# ### Let's hit the code

# %% [markdown]
# #### First, we import the conveniant libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ###### Then we insert the foursquare ids

# %%
CLIENT_ID = 'H2ZCYLL3WQPRLWD5YQL0G0AA3ACJFBCYODDLYZ1RVHKRMT2L' # your Foursquare ID
CLIENT_SECRET = 'SPMYGVNCHYI1J2X3CAMEIDXO00N43KTZPW15YTB0TWJTGRPG' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: H2ZCYLL3WQPRLWD5YQL0G0AA3ACJFBCYODDLYZ1RVHKRMT2L
# CLIENT_SECRET:SPMYGVNCHYI1J2X3CAMEIDXO00N43KTZPW15YTB0TWJTGRPG

# %% [markdown]
# ###### Now, we insert the mosq adress to get its latitude and longitude

# %%
address = 'Boulevard de la Corniche, Casablanca 20000'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 33.6044437 -7.6370095

# %% [markdown]
# ###### We define our search query as "hotel"

# %%
search_query = 'Hotel'
radius = 5000
print(search_query + ' .... OK!')
# Out:
# Hotel .... OK!

# %% [markdown]
# ###### then we create our URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=H2ZCYLL3WQPRLWD5YQL0G0AA3ACJFBCYODDLYZ1RVHKRMT2L&client_secret=SPMYGVNCHYI1J2X3CAMEIDXO00N43KTZPW15YTB0TWJTGRPG&ll=33.6044437,-7.6370095&v=20180604&query=Hotel&radius=5000&limit=100'

# %% [markdown]
# ###### We get the Json file

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e32ba19aba29700280ec345'},
#  'response': {'venues': [{'id': '4bf1a6b5324cc9b66f4acc92',
#     'name': 'Hotel Kenzi Tower',
#     'location': {'address': 'Twin Center',
#      'lat': 33.586922227009374,
#      'lng': -7.6320093864859,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 33.586922227009374,
#        'lng': -7.6320093864859}],
#      'distance': 2004,
#      'cc': 'MA',
#      'city': 'Casa',
#      'state': 'Région du Grand Casablanca',
#      'country': 'المغرب',
#      'formattedAddress': ['Twin Center', 'Casa', 'المغرب']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1580382983',
#     'hasPerk': False},
#    {'id': '4bc77d1593bdeee1db6f37ae',
# ...

# %% [markdown]
# ###### We transform the Json into a dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
data1=dataframe

# %%
dataframe.id
# Out:
# 0     4bf1a6b5324cc9b66f4acc92
# 1     4bc77d1593bdeee1db6f37ae
# 2     4b92c321f964a5205e1934e3
# 3     4da89f041e72d9bb474a5e70
# 4     4b88ea5af964a520401332e3
# 5     5396e3e8498ecef183319e7e
# 6     4b8989dbf964a520fb3f32e3
# 7     4ecd301caa1f0c71c8aadb3d
# 8     4f5146c7e4b07de37a4e89b9
# 9     4d51973a9d4937042096ce39
# 10    4bd0fba520cd99602a9b2e9e
# 11    4c9390fd72dd224b1fb69191
# 12    5879405ee612f226c8fc4f0b
# 13    4d1ed9a3756e8cfa62865e54
# 14    4dcb898ed16478749fa55902
# 15    5b642cf19e0d54002c067eea
# 16    4fa5965de4b0bbcd4a1447fd
# 17    5d9dc2f6196b510008ce9b01
# 18    4e8b0e9761afcc24d9938e67
# 19    4bc77d0d93bdeee1d86f37ae
# 20    5616fd42498e9969f1c6b8dc
# 21    4bd7485d304fce72ea4e33ab
# 22    5ca69797ccad6b0039e96ec8
# 23    4bc8e8b7762beee148ae3d38
# 24    4bbf9021b492d13a4cdea260
# 25    57e57179498e7ac958c80d18
# 26    52e453d9498eee8ae82524ba
# 27    4bc77d1c93bdeee1dd6f37ae
# 28    4bc330fedce4eee1837b719d
# 29    4ee3e1218b81bab282ef2747
# ...

# %% [markdown]
# ###### We clean the dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                           name       categories  \
# 0   Hotel Kenzi Tower                           Hotel
# 1   Hôtel Idou Anfa                             Hotel
# 2   Hotel Golden Tulip Farah                    Hotel
# 3   Hotel Prince De Paris                       Hotel
# 4   Kenzi Basma Hotel                           Hotel
# 5   Mövenpick Hotel                             Hotel
# 6   Hotel Ibis City Center                      Hotel
# 7   Hotel Central                               Roof Deck
# 8   Gray Boutique Hotel Spa                     Hotel
# 9   Hôtel Diwan                                 Hotel
# 10  Central Hotel Casablanca                    Hotel
# 11  Novotel Casablanca City Hotel               Hotel
# 12  Melliber Appart Hotel                       Hotel
# 13  Hotel Guynemer                              Hotel
# 14  Hotel Astrid                                Bed & Breakfast
# 15  Mövenpick Hotel Casablanca                  Hotel
# ...

# %%
dataframe_filtered.name
# Out:
# 0     Hotel Kenzi Tower
# 1     Hôtel Idou Anfa
# 2     Hotel Golden Tulip Farah
# 3     Hotel Prince De Paris
# 4     Kenzi Basma Hotel
# 5     Mövenpick Hotel
# 6     Hotel Ibis City Center
# 7     Hotel Central
# 8     Gray Boutique Hotel Spa
# 9     Hôtel Diwan
# 10    Central Hotel Casablanca
# 11    Novotel Casablanca City Hotel
# 12    Melliber Appart Hotel
# 13    Hotel Guynemer
# 14    Hotel Astrid
# 15    Mövenpick Hotel Casablanca
# 16    Hotel Ennasma
# 17    Radisson Blu Hotel, Casablanca City Center
# 18    Hotel Val D'Anfa
# 19    Hotel Club Val d'Anfa
# 20    Four Seasons Hotel Casablanca
# 21    Maamoura Hotel Casablanca
# 22    Hotel My Loft
# 23    Business Hotel Casablanca
# 24    Palace d'Anfa Hotel
# 25    Le Casablanca Hôtel
# 26    Imperial Hotel Piscine
# 27    Riad Salam Hotel Casablanca
# 28    Hotel Rivoli
# 29    Hotel & Spa Le Doge Casablanca
# 30    Hotel Gauthier
# 31    Hotel Palace d'Anfa فندق بلاص أنفا
# 32    Hotel Odyssee Center
# ...

# %%
###### We generate a map centred around the mosq

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Hassan 2 mosq
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the hotels as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ###### Create an URL to show the rating of the closest hotelto the mosq

# %%
venue_id = '4bf1a6b5324cc9b66f4acc92' # ID of Hotel Kenzi Tower
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4bf1a6b5324cc9b66f4acc92?client_id=H2ZCYLL3WQPRLWD5YQL0G0AA3ACJFBCYODDLYZ1RVHKRMT2L&client_secret=SPMYGVNCHYI1J2X3CAMEIDXO00N43KTZPW15YTB0TWJTGRPG&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
data2 = json_normalize(result['response']['venue'])
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'description', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 8.7

# %% [markdown]
# ###### Create an URL to show the rating of the second closest hotelto the mosq

# %%
venue_id = '4bc77d1593bdeee1db6f37ae' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.6

# %% [markdown]
# ###### Create an URL to show the rating of the third closest hotelto the mosq

# %%
venue_id = '4b92c321f964a5205e1934e3' # ID of Conca Cucina Italian Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 5.7

# %%
result['response']['venue']['tips']['count']
# Out:
# 16

# %%
## Ecco Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e32bb3b542890001be1bcb7'},
#  'response': {'tips': {'count': 16,
#    'items': [{'id': '5a367c17b9a5a814cb791af3',
#      'createdAt': 1513520151,
#      'text': 'Odalar Guzel, calisanlar cok samimi, Türkleri seviyorlar',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5a367c17b9a5a814cb791af3',
#      'lang': 'tr',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 2,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '74366645',
#       'firstName': 'Durmus',
#       'lastName': 'B',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/74366645_kWJfzF1a_74XGyRVRGXCjVEBaN2-PDug-qriHb29lx7VV3YomnmWKRidlW3cI_1NJ7NheBQ0R.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                        text  agreeCount  \
# 0  Odalar Guzel, calisanlar cok samimi, Türkleri seviyorlar  2
#
#    disagreeCount                        id user.firstName user.lastName  \
# 0  0              5a367c17b9a5a814cb791af3  Durmus         B
#
#    user.gender   user.id
# 0 NaN           74366645

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
venues
# Out:
# [{'id': '4bf1a6b5324cc9b66f4acc92',
#   'name': 'Hotel Kenzi Tower',
#   'location': {'address': 'Twin Center',
#    'lat': 33.586922227009374,
#    'lng': -7.6320093864859,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 33.586922227009374,
#      'lng': -7.6320093864859}],
#    'distance': 2004,
#    'cc': 'MA',
#    'city': 'Casa',
#    'state': 'Région du Grand Casablanca',
#    'country': 'المغرب',
#    'formattedAddress': ['Twin Center', 'Casa', 'المغرب']},
#   'categories': [{'id': '4bf58dd8d48988d1fa931735',
#     'name': 'Hotel',
#     'pluralName': 'Hotels',
#     'shortName': 'Hotel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1580382983',
#   'hasPerk': False},
#  {'id': '4bc77d1593bdeee1db6f37ae',
#   'name': 'Hôtel Idou Anfa',
#   'location': {'address': '85 boulevard Anfa',
#    'lat': 33.59249736386367,
#    'lng': -7.632720937221422,
# ...

# %%
dataframe
# Out:
#                           id                                        name  \
# 0   4bf1a6b5324cc9b66f4acc92  Hotel Kenzi Tower
# 1   4bc77d1593bdeee1db6f37ae  Hôtel Idou Anfa
# 2   4b92c321f964a5205e1934e3  Hotel Golden Tulip Farah
# 3   4da89f041e72d9bb474a5e70  Hotel Prince De Paris
# 4   4b88ea5af964a520401332e3  Kenzi Basma Hotel
# 5   5396e3e8498ecef183319e7e  Mövenpick Hotel
# 6   4b8989dbf964a520fb3f32e3  Hotel Ibis City Center
# 7   4ecd301caa1f0c71c8aadb3d  Hotel Central
# 8   4f5146c7e4b07de37a4e89b9  Gray Boutique Hotel Spa
# 9   4d51973a9d4937042096ce39  Hôtel Diwan
# 10  4bd0fba520cd99602a9b2e9e  Central Hotel Casablanca
# 11  4c9390fd72dd224b1fb69191  Novotel Casablanca City Hotel
# 12  5879405ee612f226c8fc4f0b  Melliber Appart Hotel
# 13  4d1ed9a3756e8cfa62865e54  Hotel Guynemer
# 14  4dcb898ed16478749fa55902  Hotel Astrid
# 15  5b642cf19e0d54002c067eea  Mövenpick Hotel Casablanca
# 16  4fa5965de4b0bbcd4a1447fd  Hotel Ennasma
# ...

# %%
result['response']['venue']
# Out:
# {'id': '4bc77d1593bdeee1db6f37ae',
#  'name': 'Hôtel Idou Anfa',
#  'contact': {'phone': '+212522200136', 'formattedPhone': '+212 5222-00136'},
#  'location': {'address': '85 boulevard Anfa',
#   'lat': 33.59249736386367,
#   'lng': -7.632720937221422,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 33.59249736386367,
#     'lng': -7.632720937221422}],
#   'postalCode': '20000',
#   'cc': 'MA',
#   'city': 'الدار البيضاء',
#   'state': 'Région du Grand Casablanca',
#   'country': 'المغرب',
#   'formattedAddress': ['85 boulevard Anfa', '20000 الدار البيضاء', 'المغرب']},
#  'canonicalUrl': 'https://foursquare.com/v/h%C3%B4tel-idou-anfa/4bc77d1593bdeee1db6f37ae',
#  'categories': [{'id': '4bf58dd8d48988d1fa931735',
#    'name': 'Hotel',
#    'pluralName': 'Hotels',
#    'shortName': 'Hotel',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d12f951735',
# ...

# %%
data1
# Out:
#                           id                                        name  \
# 0   4bf1a6b5324cc9b66f4acc92  Hotel Kenzi Tower
# 1   4bc77d1593bdeee1db6f37ae  Hôtel Idou Anfa
# 2   4b92c321f964a5205e1934e3  Hotel Golden Tulip Farah
# 3   4da89f041e72d9bb474a5e70  Hotel Prince De Paris
# 4   4b88ea5af964a520401332e3  Kenzi Basma Hotel
# 5   5396e3e8498ecef183319e7e  Mövenpick Hotel
# 6   4b8989dbf964a520fb3f32e3  Hotel Ibis City Center
# 7   4ecd301caa1f0c71c8aadb3d  Hotel Central
# 8   4f5146c7e4b07de37a4e89b9  Gray Boutique Hotel Spa
# 9   4d51973a9d4937042096ce39  Hôtel Diwan
# 10  4bd0fba520cd99602a9b2e9e  Central Hotel Casablanca
# 11  4c9390fd72dd224b1fb69191  Novotel Casablanca City Hotel
# 12  5879405ee612f226c8fc4f0b  Melliber Appart Hotel
# 13  4d1ed9a3756e8cfa62865e54  Hotel Guynemer
# 14  4dcb898ed16478749fa55902  Hotel Astrid
# 15  5b642cf19e0d54002c067eea  Mövenpick Hotel Casablanca
# 16  4fa5965de4b0bbcd4a1447fd  Hotel Ennasma
# ...

# %%
data2
# Out:
#                          id               name  \
# 0  4bf1a6b5324cc9b66f4acc92  Hotel Kenzi Tower
#
#                                                           canonicalUrl  \
# 0  https://foursquare.com/v/hotel-kenzi-tower/4bf1a6b5324cc9b66f4acc92
#
#                                                                                                                                                                                                            categories  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'Hotel', 'pluralName': 'Hotels', 'shortName': 'Hotel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_', 'suffix': '.png'}, 'primary': True}]
#
#    verified  dislike     ok  rating ratingColor  ratingSignals  ...  \
# 0  False     False    False  8.7     73CF42      195            ...
#
#                        bestPhoto.prefix  \
# 0  https://fastly.4sqi.net/img/general/
#
# ...
